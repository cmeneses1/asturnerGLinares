# %% [markdown]
# # Variables y listan que ayudan en la automatización: Z_Ayudas
# En este *notebook* vamos a recoger algunos datos y variables importantes en la estructura del censo de estudio. Por ejemplo, vamos a listar todas las localidades.

# %% [markdown]
# ## Lista de localidades
# Esta variable es un diccionario cuyas claves son las entradas de localidades del censo (nótese que están en mayúsuculas). Luego, los valores son los nombres actuales de las localidades (nótese que están en minúsculas). Son los valores los que usaremos para acceder a la geolocalización. Nótese también las localidades en censo txt deben aparecer en mayúsculas y sin tildes, de la misma forma que aparecen aquí.

# %%
ayuda_localidades = {   
    'ARANIEGO DE ARRIBA' : 'Parajas',    
    'ARANIEGO (PARAJAS)' : 'Parajas',    
    'ARGANCINAS': 'Argancinas',    
    'ARGANZINAS': 'Argancinas',    
    'BERDUCEDO': 'Berducedo',    
    'BERDUZEDO': 'Berducedo',    
    'TRAPA': 'Trapa',
    'TEIJEDO': 'Teijedo',
    'TEINEDO': 'Teijedo',    
    'TEIXEDO': 'Teijedo',    
    'CASTIELLO': 'Castello',    
    'CASTELLO': 'Castello',    
    'BALDEDO': 'Baldedo',    
    'CASTRO': 'Castro, El',    
    'LA GRANDERA': 'Grandera, La',    
    'CORONDEÑO': 'Corondeño',    
    'FORNIELLAS': 'Forniellas',
    'FUENTES': 'Fuentes',    
    'FONTES': 'Fuentes',    
    'NOCEDA': 'Noceda',    
    'NOZEDA': 'Noceda',    
    'YBOLLO': 'Iboyo',    
    'EYBOLLO': 'Iboyo',    
    'IBOYO': 'Iboyo',    
    'CONBA': 'Comba',    
    'COMBA': 'Comba',    
    'BESULLO': 'Besullo',    
    'CELON': 'Celón',    
    'ZELON': 'Celón',    
    'CELÓN': 'Celón',    
    'ZELÓN': 'Celón',    
    'LA VEGA': 'Vega de Truelles, La', 
    'PUMAR': 'Pumar',    
    'ERIAS': 'Herías',    
    'HERIAS': 'Herías',     
    'SARZOL': 'Sarzol',    
    'NABEDO': 'Navedo',    
    'RIODEVILLAR': 'Río de Villar',
    'LAGO': 'Lago',
    'MONTEFURADO': 'Montefurado',
    'CARCEDO': 'Carcedo de Lago; Carcedo de Lomes',
    'ARMENANDE': 'Armenande',
    'BILLAR': 'Villardejusto',
    'BILLAR DE SAN PEDRO': 'Villar de Castanedo',
    'CASTANEDO': 'Castanedo',
    'SAN PEDRO': 'San Pedro',
    'CARZEDO': 'Carcedo de Lago; Carcedo de Lomes',
    'VILLAR DE ARMENANDE': 'Villardejusto',
    'SAN PEDRO': 'San Pedro',
    'VILLAR DE SAN PEDRO': 'Villar de Castanedo',
    'LINARES': 'Linares',
    'ARGANZUA': 'Arganzúa',
    'LLOMES': 'Lomes',
    'LOMES': 'Lomes',
    'EL OTERO': 'Otero',
    'TARALLE': 'Tarallé',
    'LA POLA': 'Pola de Allande',
    'LA REIGADA': 'Reigada, La',
    'EL MAZO DE PEÑASEITA': 'Peñaseita',
    'EL MAZO DE COLOBREDO': 'Colobredo',
    'EL MAZO DE ABAJO': 'Mazo, El',
    'FRESNEDO': 'Fresnedo; Fresnedo de San Emiliano',
    'CERECEDA': 'Cereceda',
    'BALBONA': 'Valbona',
    'VILLAFRONTUN': 'Villafrontú',
    'FERROY': 'Ferroy',
    'EL CALEYO': 'Caleyo',
    'CIMADEVILLA': 'Cimadevilla',
    'LA RAYGADA': 'Reigada, La',
    'PENASEITA': 'Peñaseita',
    'COLUBREDO': 'Colobredo',
    'MAZO DE AVAXO': 'Mazo, El',
    'CEREZEDA': 'Cereceda',
    'VILLAFRONTTUN': 'Villafrontú',
    'PRESNAS': 'Presnas',
    'LUGAR DE PRESNAS': 'Presnas',
    'SANTO MILLANO': 'San Emiliano',
    'MURIAS': 'Murias',
    'EL TRIGALEDO': 'Trigaledo, El',
    'BALLINAS': 'Vallinas',
    'HEMA': 'Ema',
    'LA QUINTANA': 'Quintana, La',
    'VALLINAS': 'Vallinas',
    'VILLADECABO': 'Villadecabo',
    'BUSLABIN': 'Buslavín',
    'LA FIGUERINA':'Figuerina, La',
    'BEBERASO':'Beveraso',
    'BOXO': 'Bojo',
    'TAMAGORDAS': 'Tamagordas',
    'CERNIAS': 'Cernías',
    'ESTELA': 'Estela',
    'RUY DE COBA': 'Riodecoba',
    'RIO DE COBA': 'Riodecoba',
    'SA MARTIN DE BEDULEDO': 'San Martín de Beduledo',
    'SA MARTIN': 'San Martín de Beduledo',
    'SAN MARTIN DE VEDULEDO': 'San Martín de Beduledo',
    'SANTA COLOMBA': 'Santa Coloma',
    'CABRAL': 'Cabral',
    'EL SELLON': 'Sellón, El',
    'MIERES': 'Meres',
    'BUSTEL': 'Bustel',
    'LA PUENTENUEBA': 'Pontenova',
    'ARBEYALES': 'Arbeyales',
    'EL CALEYO': 'Caleyo, El',
    'BALLINADOSSA': 'Vallinadosa',
    'LLANECES': 'Llances',
    'MONON': 'Monón',
    'LUGAR DE YSS': 'Is',
    'BENDON': 'Bendón',
    'MURIELLOS': 'Muriellos',
    'EL REBOLLO': 'Rebollo, El',
    'LA FOLGUERIZA': 'Folgueriza, La',
    'BUSTANTIGO': 'Bustantigo',
    'SANTA COLOMA': 'Santa Coloma',
    'SANTTA COLOMA': 'Santa Coloma',
    'BUSTTEL': 'Bustel',
    'MIERES': 'Meres',
    'VALLINADOSA': 'Vallinadosa',
    'LLANEZES': 'Llances',
    'IS': 'Is',
    'VENDON': 'Bendón',
    'LA PORQUERA': 'Porquera, La',
    'FOLGUERIZA': 'Folgueriza, La',
    'EL PLANTADO': 'Plantao, El',
    'BALLEDOR': 'San Martín del Valledor',
    'SAN MARTIN DEL BALLEDOR': 'San Martín del Valledor',
    'ROBLEDO': 'Robledo',
    'VILLASONTE': 'Villasonte',
    'SANCEDO': 'Salcedo',
    'EL ENGERTAL': 'Engertal, El',
    'EL PROBO': 'Provo, El',
    'TREMADO': 'Tremado',
    'CORNOLLO': 'Cornollo',
    'PARADAS': 'Paradas',
    'BUSBIDAL': 'Busvidal',
    'COBA': 'Coba',
    'RUBIEIRO': 'Rubieiro',
    'AGUANES': 'Aguanes',
    'TRABACES': 'Trabaces',
    'COLLADA': 'Collada',
    'BARRAS': 'Barras',
    'VILLANUEBA': 'Villanueva',
    'FONTETA': 'Fonteta',
    'VILLALAYN': 'Villalaín',
    'SAN SALVADOR': 'San Salvador',
    'BUSTAREL': 'Bustarel',
    'VALLEDOR': 'San Martín del Valledor',
    'SAN MARTIN': 'San Martín del Valledor',
    'ROBLEDO': 'Robledo',
    'VILLASONTE': 'Villasonte',
    'SALZEDO': 'Salcedo',
    'YNXERTTAL': 'Engertal, El',
    'EL PROBO': 'Provo, El',
    'TREMADO': 'Tremado',
    'SAN SALVADOR': 'San Salvador',
    'BUSTAREL': 'Bustarel',
    'VILLALAIN': 'Villalaín',
    'VILLANUEVA': 'Villanueva',
    'BARRAS': 'Barras',
    'TRABAZES': 'Trabaces',
    'AGUANES': 'Aguanes',
    'FURADA': 'Furada, La',
    'CORNOLLO': 'Cornollo',
    'PARADAS': 'Paradas',
    'BUSBIDAL': 'Busvidal',
    'BILLABRUFE': 'Villagrufe',
    'VILLAGRUFE': 'Villagrufe',
    'TAMUÑO': 'Tamuño',
    'CARBALLEDO': 'Carballedo',
    'PRADIELLA': 'Pradiella',
    'SANTULLANO': 'Santullano',
    'PRADA': 'Prada',
    'CARVALLEDO': 'Carballedo',
    'VILLAR DE SAPOS': 'Villar de Sapos',
    'BILLAR DE SAPOS': 'Villar de Sapos',
    'SELCE': 'Selce',
    'ALMOÑO': 'Almoño',
    'VILLAR': 'Villar de Sapos',
    'SELZE': 'Selce',
    'VILLABASER': 'Villavaser',
    'VILLABASER DE ABAJO': 'Villavaser',
    'PINIELLA': 'Piniella',
    'FIGUERAS': 'Figueras',
    'VILLAVERDE': 'Villaverde',
    'LANTIGO': 'Lantigo',
    'VALLE': 'Valle, El',
    'ABANIELLA': 'Abaniella',
    'PERULLEDA': 'Peruyeda',
    'SANTA OLALLA': 'Santa Eulalia',
    'VILLABERDE': 'Villaverde',
    'SANTA EULALIA': 'Santa Eulalia'    
}

# %% [markdown]
# ## Lista de etiquetas "PER" espurias
# Esta variable es una lista cuyas entradas son frases y  palabras que el procesador de Stanza identifica como personas, pero en realidad, no son individuos del censo. Las cadenas de texto de esta lista serán eliminadas de las entidades "PER" encontradas, por lo tanto, hay que tener cuidado de no añadir a esta lista casos ambiguos en los que unas veces sí son individuos y otras veces no.

# %%
coincidencias_espurias = [
    'Merino', 'Justicia Mayor', 'Su Señoría', 'Escribano', 'Teniente de Merino', 'Justicia Mayor del Concejo de Allande', 'Dueño',
    'Señor de la Jurisdicción', 'Procurador Síndico General', 'Escribano', 'Cura', 'Padron', 'Casa del Balledor', 'Número',
    'Theniente de Merino', 'Conzexo','Presbítero', 'Padrón', 'Casa', 'Casas de Valledor', 'Hijodalgo Notorio', 'Hijosdalgo',
    'Hijosdalgo Notorios', 'Lago', 'Señor Rexente', 'Pechero', 'Hijosdalgo de Carta', 'Noble', 'Hidalgos', 'Idalgos', 'Señor', 'Páramo',
    'Procurador General', 'Abogado de los Reales Concejos', 'Conde Marzel de Peñalba', 'Señor de este Qonzexo', 'Qoncexo', 'Armas',
    'Mayordomo', 'Conde', 'Presbitero', 'Escribano de Numero', 'Empadronador Noble', 'Padronero', 'Lano', 'Hixosdalgo', 'Ldo', 'El Ldo',
    'Clérigo', 'Escribano de S.M.', 'Cura Parroco', 'S. Mrd.', 'Coloma', 'Casas del Balledor', 'Cura de San Martín del Balledor',
    'Presbítero' , 'Padroneros', 'Procurador', 'Bauptizados', 'Procurador del estado Llano', 'Ojo', 'Theniente', 'Procurador Llano',
    'Linaje de Queipos', 'Cura de Villabrufe', 'Procurador General', 'Id', 'Cura de Villar de Sapos', 'Casas de Llano', 'Casas', 
    'Arcipreste de Allande', 'Villaverde', 'Celón', 'Casa de Arganzúa', 'Carta Executtoria', 'Cartta Executtoria'
]

for clave in ayuda_localidades.keys():
    coincidencias_espurias.append(clave)

# %% [markdown]
# ## Lista de parroquias
# Esta variable da las entradas exactas de las parroquias. Nótese que están en mayúsculas. Así es como deben aparecer en el censo txt.

# %%
ayuda_parroquias = {
    'PARROQUIA DE ARANIEGO (PARAJAS)': 'Parajas',   
    'PARROQUIA DE BERDUCEDO': 'Berducedo',
    'PARROQUIA DE BERDUZEDO': 'Berducedo',
    'PARROQUIA DE BESULLO': 'Besullo',
    'PARROQUIA DE CELON': 'Celón',
    'PARROQUIA DE ZELON': 'Celón',
    'PARROQUIA DE ERIAS': 'Herías',
    'PARROQUIA DE HERIAS': 'Herías',
    'PARROQUIA DE LAGO': 'Lago',
    'PARROQUIA DE LINARES': 'Linares',
    'PARROQUIA DE LLOMES (LOMES)': 'Lomes',
    'PARROQUIA DE LOMES': 'Lomes',
    'PARROQUIA DE LA POLA': 'Pola de Allande',
    'PARROQUIA DE PRESNAS': 'Presnas',
    'PARROQUIA DE SANTO MILLANO': 'San Emiliano',
    'PARROQUIA DE SA MARTIN DE BEDULEDO': 'San Martín de Beduledo',
    'PARROQUIA DE SAN MARTIN DE VEDULEDO': 'San Martín de Beduledo',
    'PARROQUIA DE SANTA COLOMBA': 'Santa Coloma',
    'PARROQUIA DE SANTA COLOMA': 'Santa Coloma',
    'PARROQUIA DEL BALLEDOR': 'San Martín del Valledor',
    'PARROQUIA DEL VALLEDOR': 'San Martín del Valledor',
    'PARROQUIA DE VILLABRUFE (VILLAGRUFE)': 'Villagrufe',
    'PARROQUIA DE VILLAGRUFE': 'Villagrufe',
    'PARROQUIA DE VILLAR DE SAPOS': 'Villar de Sapos',
    'FELIGRESIA DE VILLAR DE SAPOS': 'Villar de Sapos',
    'PARROQUIA DE VILLABASER': 'Villavaser',
    'PARROQUIA DE VILLAVERDE': 'Villaverde',
    'PARROQUIA DE VILLABERDE': 'Villaverde',
}

# %% [markdown]
# ## Variable de longitud y latutid
# Esta variable se ha logrado hacer con web scraping. Agradecemos el código de [ayhon](https://github.com/ayhon/GeolocalizacionPueblosAsturias) que me ha servido de base para realizar la extracción de la página web [pueblosdeasturias.es](https://www.pueblosdeasturias.es/). No se debe olvidar la segunda celda de este apartado. Esta última completa la información que pueblosdeasturias.es no tiene y que he conseguido a mano.

# %%
longitud_latitud = {
    'Parajas': {'Latitud': 43.2016456, 'Longitud': -6.585278},
    'Argancinas': {'Latitud': 43.2064324, 'Longitud': -6.5874077},
    'Berducedo': {'Latitud': 43.2329138, 'Longitud': -6.7676724},
    'Trapa': {'Latitud': 43.2566454, 'Longitud': -6.7852052},
    'Teijedo': {'Latitud': 43.2545971, 'Longitud': -6.7749775},
    'Castello': {'Latitud': 43.2529118, 'Longitud': -6.7626349},
    'Baldedo': {'Latitud': 43.2480584, 'Longitud': -6.7673603},
    'Castro, El': {'Latitud': 43.2702311, 'Longitud': -6.7512008},
    'Grandera, La': {'Latitud': None, 'Longitud': None},
    'Corondeño': {'Latitud': 43.2636188, 'Longitud': -6.7713329},
    'Forniellas': {'Latitud': 43.1999761, 'Longitud': -6.6282732},
    'Fuentes': {'Latitud': None, 'Longitud': None},
    'Noceda': {'Latitud': 43.1944265, 'Longitud': -6.6178032},
    'Iboyo': {'Latitud': 43.2108331, 'Longitud': -6.6354339},
    'Comba': {'Latitud': 43.2042325, 'Longitud': -6.6444941},
    'Besullo': {'Latitud': 43.1869801, 'Longitud': -6.6329396},
    'Celón': {'Latitud': 43.2402821, 'Longitud': -6.5825589},
    'Vega de Truelles, La': {'Latitud': 43.2278243, 'Longitud': -6.5844473},
    'Pumar': {'Latitud': 43.2305154, 'Longitud': -6.5885858},
    'Herías': {'Latitud': 43.3154383, 'Longitud': -6.805375},
    'Sarzol': {'Latitud': 43.3261506, 'Longitud': -6.8221276},
    'Navedo': {'Latitud': 43.3197513, 'Longitud': -6.7777945},
    'Río de Villar': {'Latitud': None, 'Longitud': None},
    'Lago': {'Latitud': 43.2533629, 'Longitud': -6.7321047},
    'Montefurado': {'Latitud': 43.2660529, 'Longitud': -6.6946773},
    'Carcedo de Lago': {'Latitud': 43.2420634, 'Longitud': -6.736366},
    'Carcedo de Lomes': {'Latitud': 43.2141137, 'Longitud': -6.5701844},
    'Armenande': {'Latitud': 43.2344383, 'Longitud': -6.7415478},
    'Villardejusto': {'Latitud': 43.2287387, 'Longitud': -6.7410068},
    'Villar de Castanedo': {'Latitud': 43.2675174, 'Longitud': -6.7116478},
    'Castanedo': {'Latitud': 43.2675174, 'Longitud': -6.7116478},
    'San Pedro': {'Latitud': 43.2673257, 'Longitud': -6.7248198},
    'Linares': {'Nombre': 'Linares', 'Latitud': None, 'Longitud': None},
    'Arganzúa': {'Latitud': 43.2381359, 'Longitud': -6.5405136},
    'Lomes': {'Latitud': 43.2141137, 'Longitud': -6.5701844},
    'Otero': {'Latitud': 43.2260237, 'Longitud': -6.5622274},
    'Tarallé': {'Latitud': 43.2169972, 'Longitud': -6.5784209},
    'Pola de Allande': {'Latitud': None, 'Longitud': None},
    'Reigada, La': {'Latitud': None, 'Longitud': None},
    'Peñaseita': {'Latitud': None, 'Longitud': None},
    'Colobredo': {'Latitud': 43.2822369, 'Longitud': -6.6283227},
    'Mazo, El': {'Latitud': 43.2728346, 'Longitud': -6.6205657},
    'Fresnedo': {'Latitud': None, 'Longitud': None},
    'Fresnedo de San Emiliano': {'Latitud': 43.2574581, 'Longitud': -6.8336809},
    'Cereceda': {'Latitud': 43.2578766, 'Longitud': -6.6035813},
    'Valbona': {'Latitud': 43.2617475, 'Longitud': -6.590518},
    'Villafrontú': {'Latitud': 43.2719865, 'Longitud': -6.5982218},
    'Ferroy': {'Latitud': 43.2799489, 'Longitud': -6.6033123},
    'Caleyo, El': {'Latitud': 43.272181, 'Longitud': -6.7358577},
    'Cimadevilla': {'Latitud': None, 'Longitud': None},
    'Presnas': {'Latitud': 43.2295493, 'Longitud': -6.5761443},
    'San Emiliano': {'Latitud': 43.2574581, 'Longitud': -6.8336809},
    'Murias': {'Latitud': 43.2473996, 'Longitud': -6.832618},
    'Trigaledo, El': {'Nombre': 'Trigaledo, El', 'Latitud': None, 'Longitud': None},
    'Vallinas': {'Latitud': 43.2655327, 'Longitud': -6.8253966},
    'Ema': {'Latitud': 43.263044, 'Longitud': -6.8201096},
    'Quintana, La': {'Latitud': 43.2675674, 'Longitud': -6.8155934},
    'Villadecabo': {'Latitud': 43.266058, 'Longitud': -6.8096113},
    'Buslavín': {'Latitud': 43.2557835, 'Longitud': -6.7996059},
    'Figuerina, La': {'Latitud': 43.2345953, 'Longitud': -6.7999155},
    'Beveraso': {'Latitud': 43.2781441, 'Longitud': -6.7986945},
    'Bojo': {'Latitud': 43.2788464, 'Longitud': -6.7843805},
    'Tamagordas': {'Latitud': 43.2910992, 'Longitud': -6.8251577},
    'Cernías': {'Latitud': 43.2996843, 'Longitud': -6.8277327},
    'Estela': {'Latitud': 43.2950755, 'Longitud': -6.7974456},
    'Riodecoba': {'Latitud': 43.3073637, 'Longitud': -6.7926056},
    'San Martín de Beduledo': {'Latitud': 43.2361028, 'Longitud': -6.5938196},
    'Santa Coloma': {'Latitud': 43.2960698, 'Longitud': -6.7252148},
    'Cabral': {'Latitud': 43.3020667, 'Longitud': -6.7111294},
    'Sellón, El': {'Latitud': 43.2925072, 'Longitud': -6.7263337},
    'Meres': {'Latitud': None, 'Longitud': None},
    'Bustel': {'Latitud': 43.2893098, 'Longitud': -6.721016},
    'Pontenova': {'Latitud': None, 'Longitud': None},
    'Arbeyales': {'Latitud': None, 'Longitud': None},
    'Vallinadosa': {'Latitud': None, 'Longitud': None},
    'Llances': {'Nombre': 'Llances', 'Latitud': None, 'Longitud': None},
    'Monón': {'Latitud': 43.2946943, 'Longitud': -6.737048},
    'Is': {'Nombre': 'Is', 'Latitud': None, 'Longitud': None},
    'Bendón': {'Latitud': 43.2999849, 'Longitud': -6.7436019},
    'Muriellos': {'Latitud': 43.3053548, 'Longitud': -6.737544},
    'Rebollo, El': {'Latitud': 43.3215955, 'Longitud': -6.7111464},
    'Folgueriza, La': {'Latitud': 43.3482941, 'Longitud': -6.6910096},
    'Bustantigo': {'Latitud': 43.359591, 'Longitud': -6.6895435},
    'Porquera, La': {'Latitud': None, 'Longitud': None},
    'Plantao, El': {'Latitud': None, 'Longitud': None},
    'San Martín del Valledor': {'Latitud': 43.1779708, 'Longitud': -6.7741057},
    'Robledo': {'Latitud': 43.1855984, 'Longitud': -6.7654259},
    'Villasonte': {'Latitud': None, 'Longitud': None},
    'Salcedo': {'Latitud': 43.2013551, 'Longitud': -6.7615475},
    'Engertal, El': {'Latitud': 43.2071312, 'Longitud': -6.7579963},
    'Provo, El': {'Latitud': 43.2169103, 'Longitud': -6.7527332},
    'Tremado': {'Latitud': 43.1700598, 'Longitud': -6.7903301},
    'Cornollo': {'Latitud': 43.17112, 'Longitud': -6.8165671},
    'Paradas': {'Latitud': None, 'Longitud': None},
    'Busvidal': {'Latitud': 43.2005095, 'Longitud': -6.8174364},
    'Coba': {'Latitud': 43.177474, 'Longitud': -6.7657864},
    'Furada, La': {'Latitud': 43.1713428, 'Longitud': -6.7583648},
    'Rubieiro': {'Latitud': 43.1684703, 'Longitud': -6.771065},
    'Aguanes': {'Latitud': 43.1558756, 'Longitud': -6.7692736},
    'Trabaces': {'Latitud': 43.1478821, 'Longitud': -6.771129},
    'Collada': {'Latitud': None, 'Longitud': None},
    'Barras': {'Latitud': None, 'Longitud': None},
    'Villanueva': {'Latitud': 43.1440866, 'Longitud': -6.7949573},
    'Fonteta': {'Latitud': None, 'Longitud': None},
    'Villalaín': {'Latitud': 43.1224534, 'Longitud': -6.8133427},
    'San Salvador': {'Latitud': None, 'Longitud': None},
    'Bustarel': {'Latitud': None, 'Longitud': None},
    'Villagrufe': {'Latitud': 43.2442678, 'Longitud': -6.5995361},
    'Tamuño': {'Latitud': None, 'Longitud': None},
    'Carballedo': {'Latitud': None, 'Longitud': None},
    'Pradiella': {'Latitud': 43.2400293, 'Longitud': -6.6180261},
    'Santullano': {'Latitud': None, 'Longitud': None},
    'Prada': {'Latitud': 43.2384413, 'Longitud': -6.6287743},
    'Villar de Sapos': {'Latitud': 43.2039077, 'Longitud': -6.5953287},
    'Selce': {'Latitud': None, 'Longitud': None},
    'Almoño': {'Latitud': None, 'Longitud': None},
    'Villavaser': {'Latitud': 43.2437755, 'Longitud': -6.578371},
    'Piniella': {'Latitud': None, 'Longitud': None},
    'Figueras': {'Latitud': 43.2540035, 'Longitud': -6.5776323},
    'Villaverde': {'Latitud': 43.2262624, 'Longitud': -6.6087403},
    'Lantigo': {'Latitud': 43.2264554, 'Longitud': -6.6153677},
    'Valle, El': {'Latitud': None, 'Longitud': None},
    'Abaniella': {'Latitud': 43.219795, 'Longitud': -6.6159873},
    'Peruyeda': {'Latitud': 43.2124106, 'Longitud': -6.6267596},
    'Santa Eulalia': {'Latitud': 43.2239258, 'Longitud': -6.598798}
}

# %%
longitud_latitud['Grandera, La'] = {'Latitud': 43.268669, 'Longitud': -6.774232}
longitud_latitud['Fuentes'] = {'Latitud': 43.196790, 'Longitud': -6.616097}
longitud_latitud['Río de Villar'] = {'Latitud': 43.321479, 'Longitud': -6.800871}
longitud_latitud['Linares'] = {'Latitud': 43.233823, 'Longitud': -6.562501}
longitud_latitud['Pola de Allande'] = {'Latitud': 43.271754, 'Longitud': -6.611161}
longitud_latitud['Reigada, La'] = {'Latitud': 43.291497, 'Longitud': -6.657195}
longitud_latitud['Peñaseita'] = {'Latitud': 43.2826, 'Longitud': -6.6352}
longitud_latitud['Fresnedo'] = {'Latitud': 43.266826, 'Longitud': -6.619494}
longitud_latitud['Cimadevilla'] = {'Latitud': 43.27484, 'Longitud': -6.61511}
longitud_latitud['Meres'] = {'Latitud': 43.292, 'Longitud': -6.7253}
longitud_latitud['Pontenova'] = {'Latitud': 43.27599, 'Longitud': -6.73081}
longitud_latitud['Arbeyales'] = {'Latitud': 43.28138, 'Longitud': -6.72776}
longitud_latitud['Vallinadosa'] = {'Latitud': 43.29101, 'Longitud': -6.71304}
longitud_latitud['Llances'] = {'Latitud': 43.28506, 'Longitud': -6.74181}
longitud_latitud['Is'] = {'Latitud': 43.28503, 'Longitud': -6.75724}
longitud_latitud['Porquera, La'] = {'Latitud': 43.31615, 'Longitud': -6.72182}
longitud_latitud['Plantao, El'] = {'Latitud': 43.36269, 'Longitud': -6.68580}
longitud_latitud['Villasonte'] = {'Latitud': 43.19069, 'Longitud': -6.76500}
longitud_latitud['Paradas'] = {'Latitud': 43.1885, 'Longitud': -6.8179}
longitud_latitud['Collada'] = {'Latitud': 43.15628, 'Longitud': -6.79200}
longitud_latitud['Barras'] = {'Latitud': 43.14939, 'Longitud': -6.79432}
longitud_latitud['Fonteta'] = {'Latitud': 43.13617, 'Longitud': -6.80743}
longitud_latitud['San Salvador'] = {'Latitud': 43.15547, 'Longitud': -6.80500}
longitud_latitud['Bustarel'] = {'Latitud': 43.16078, 'Longitud': -6.83129}
longitud_latitud['Tamuño'] = {'Latitud': 43.25211, 'Longitud': -6.59119}
longitud_latitud['Carballedo'] = {'Latitud': 43.24076, 'Longitud': -6.60469}
longitud_latitud['Santullano'] = {'Latitud': 43.24249, 'Longitud': -6.61762}
longitud_latitud['Selce'] = {'Latitud': 43.20107, 'Longitud': -6.60395}
longitud_latitud['Almoño'] = {'Latitud': 43.20816, 'Longitud': -6.60055}
longitud_latitud['Piniella'] = {'Latitud': 43.24747, 'Longitud': -6.58049}
longitud_latitud['Valle, El'] = {'Latitud': 43.22284, 'Longitud': -6.61701}

## No logro encontrar referencias a "El Trigaledo". Sólo que en el censo de 1773 aparece junto con Murias. Por ello, le daré las coordenadas de Murias.
longitud_latitud['Trigaledo, El'] = {'Latitud': 43.2473996, 'Longitud': -6.832618}
